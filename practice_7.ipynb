# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# step_1:read the data

# %%
path7=r"C:\Users\ASUS\Documents\python\Practice\pandass_practice\bank.csv"
bank7=pd.read_csv(path7,sep=";")

# %%
bank7
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cat7=bank7.select_dtypes(include="object").columns
num7=bank7.select_dtypes(exclude="object").columns

# %%
cat7
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num7
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for i in range(1,3):
    values=bank7[cat7[i]].value_counts().values
    keys=bank7[cat7[i]].value_counts().keys()
    bankdf7=pd.DataFrame(keys,values,columns=[cat7[i],'values'])
    print(f"............{cat7[i]}..................")
    print(bankdf7)
# Out:
# ............marital..................
#        marital values
# 2797   married    NaN
# 1196    single    NaN
# 528   divorced    NaN
# ............education..................
#       education values
# 2306  secondary    NaN
# 1350   tertiary    NaN
# 678     primary    NaN
# 187     unknown    NaN

# %%
plt.figure(figsize=(10,5))
colors=['red','green','blue','yellow']
for i in range(1,3):
    values=bank7[cat7[i]].value_counts().values
    keys=bank7[cat7[i]].value_counts().keys()
    plt.subplot(1,2,i).bar(keys,values,color=colors)
    plt.xlabel(cat7[i])
    plt.ylabel("frequency")
    plt.title("bar_chart")
    plt.savefig("continent.jpg")

# %%
plt.figure(figsize=(10,5))
for i in range(1,3):
    value7=bank7[cat7[i]].value_counts().values
    keys7=bank7[cat7[i]].value_counts().keys()
    uni_keys=bank7[cat7[i]].value_counts().unique()
    plt.subplot(2,2,i).pie(value7,labels=keys7,autopct='%0.2f%%',
                          explode=[0.05 for i in range(len(uni_keys))],
                          shadow=True,
                          startangle=180)

# %%
bank7.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank_data7=bank7['age']

# %%
bank_data7
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
plt.hist(bank_data7)
# Out:
# (array([ 111.,  944., 1235.,  869.,  612.,  576.,  100.,   36.,   30.,
#            8.]),
#  array([19. , 25.8, 32.6, 39.4, 46.2, 53. , 59.8, 66.6, 73.4, 80.2, 87. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(bank_data7)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x271e6719550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x271e6719ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x271e66d8080>],
#  'medians': [<matplotlib.lines.Line2D at 0x271e6719f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x271e671a240>],
#  'means': []}

# %%
plt.boxplot(bank_data7,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x271e6a24260>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x271e6a24830>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x271e675ff50>],
#  'medians': [<matplotlib.lines.Line2D at 0x271e6a24ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x271e6a24f80>],
#  'means': []}

# %%
plt.subplot(2,1,1).hist(bank_data7)
plt.subplot(2,1,2).boxplot(bank_data7,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x271e640c620>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x271e64e2a20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x271e640d8b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x271e626e240>],
#  'fliers': [<matplotlib.lines.Line2D at 0x271e626eba0>],
#  'means': []}

# %%
id_col=bank7['marital']
col=bank7['poutcome']
r1=pd.crosstab(id_col,col)
r1
# Out:
# poutcome  failure  other  success  unknown
# marital
# divorced       52     23       10      443
# married       298    112       82     2305
# single        140     62       37      957

# %%
id_col=bank7['marital']
col=bank7['poutcome']
r2=pd.crosstab(col,id_col)
r2
# Out:
# marital   divorced  married  single
# poutcome
# failure         52      298     140
# other           23      112      62
# success         10       82      37
# unknown        443     2305     957

# %%
r1.plot(kind="bar")
# Out:
# <Axes: xlabel='marital'>

# %%
r2.plot(kind='bar')
# Out:
# <Axes: xlabel='poutcome'>

# %%
bank7.corr(numeric_only=True)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
corr7=bank7.corr(numeric_only=True)
sns.heatmap(corr7,annot=True)
# Out:
# <Axes: >

# %%
col1=bank7['pdays']
col2=bank7['age']
col3=bank7['duration']
plt.figure(figsize=(14,5))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)
