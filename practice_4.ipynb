# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path4=r"C:\Users\ASUS\Documents\python\Practice\pandass_practice\bank.csv"
bank4=pd.read_csv(path4,sep=";")

# %%
bank4
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cat4=bank4.select_dtypes(include="object").columns
num4=bank4.select_dtypes(exclude="object").columns

# %%
cat4
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num4
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for i in range(0,len(cat4)):
    values=bank4[cat4[i]].value_counts().values
    keys=bank4[cat4[i]].value_counts().keys()
    bankdf4=pd.DataFrame(zip(keys,values),columns=[cat4[i],'values'])
    print(f"...............{cat4[i]}..........")
    print(bankdf4)
# Out:
# ...............job..........
#               job  values
# 0      management     969
# 1     blue-collar     946
# 2      technician     768
# 3          admin.     478
# 4        services     417
# 5         retired     230
# 6   self-employed     183
# 7    entrepreneur     168
# 8      unemployed     128
# 9       housemaid     112
# 10        student      84
# 11        unknown      38
# ...............marital..........
#     marital  values
# 0   married    2797
# 1    single    1196
# 2  divorced     528
# ...............education..........
#    education  values
# 0  secondary    2306
# 1   tertiary    1350
# 2    primary     678
# 3    unknown     187
# ...............default..........
#   default  values
# 0      no    4445
# 1     yes      76
# ...............housing..........
#   housing  values
# 0     yes    2559
# 1      no    1962
# ...............loan..........
#   loan  values
# 0   no    3830
# 1  yes     691
# ...............contact..........
# ...

# %%
for i in range(1,3):
    value4=bank4[cat4[i]].value_counts().values
    keys4=bank4[cat4[i]].value_counts().keys()
    bankdf4=pd.DataFrame(zip(keys4,value4),columns=[cat4[i],'values'])
    print(f"...................{cat4[i]}...............")
    print(bankdf4)
# Out:
# ...................marital...............
#     marital  values
# 0   married    2797
# 1    single    1196
# 2  divorced     528
# ...................education...............
#    education  values
# 0  secondary    2306
# 1   tertiary    1350
# 2    primary     678
# 3    unknown     187

# %%
plt.figure(figsize=(10,8))
colors4=['red','green','yellow','black']
for i in range(1,3):
    values4=bank4[cat4[i]].value_counts().values
    keys4=bank4[cat4[i]].value_counts().keys()
    plt.subplot(2,2,i).bar(keys4,values4,color=colors4)
    plt.xlabel(cat4[i])
    plt.ylabel("frequency")
    plt.title("Bar_Chart")
    plt.savefig("marital.jpg")

# %%
plt.figure(figsize=(10,5))
for i in range(1,3):
    keys4=bank4[cat4[i]].value_counts().keys()
    values4=bank4[cat4[i]].value_counts().values
    values_uni4=bank4[cat4[i]].unique()
    plt.subplot(2,2,i).pie(values4,labels=keys4,autopct='%0.2f%%',
                          explode=[0.1 for i in range(len(values_uni4))],
                          shadow=True,
                          startangle=180)

# %%
bank4.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bankd4=bank4['pdays']

# %%
bankd4
# Out:
# 0        -1
# 1       339
# 2       330
# 3        -1
# 4        -1
#        ...
# 4516     -1
# 4517     -1
# 4518     -1
# 4519    211
# 4520    249
# Name: pdays, Length: 4521, dtype: int64

# %%
plt.hist(bankd4)
# Out:
# (array([3.759e+03, 2.480e+02, 2.000e+02, 1.700e+02, 1.230e+02, 1.300e+01,
#         1.000e+00, 3.000e+00, 1.000e+00, 3.000e+00]),
#  array([ -1. ,  86.2, 173.4, 260.6, 347.8, 435. , 522.2, 609.4, 696.6,
#         783.8, 871. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(bankd4)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29d22deb3e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29d22deb950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29d22d77dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29d22debdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29d22e60080>],
#  'means': []}

# %%
plt.boxplot(bankd4,vert=False)
plt.show()

# %%
plt.subplot(2,1,1).hist(bankd4)
plt.subplot(2,1,2).boxplot(bankd4,vert=False)
plt.show()

# %%
id_col=bank4['marital']
col=bank4['poutcome']
r1=pd.crosstab(id_col,col)# its work in only on th a categorical column
r1
# Out:
# poutcome  failure  other  success  unknown
# marital
# divorced       52     23       10      443
# married       298    112       82     2305
# single        140     62       37      957

# %%
r1.plot(kind="bar")
# Out:
# <Axes: xlabel='marital'>

# %%
bank4.corr(numeric_only=True)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
corr1=bank4.corr(numeric_only=True)
sns.heatmap(corr1,annot=True)
# Out:
# <Axes: >

# %%
col1=bank4['pdays']
col2=bank4['duration']
col3=bank4['balance']
plt.figure(figsize=(14,5))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)
