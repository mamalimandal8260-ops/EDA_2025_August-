# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# step_1:read the data

# %%
path5=r"C:\Users\ASUS\Documents\python\Practice\pandass_practice\bank.csv"
bank5=pd.read_csv(path5,sep=";")

# %%
bank5
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cat5=bank5.select_dtypes(include="object").columns
num5=bank5.select_dtypes(exclude="object").columns

# %%
cat5
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num5
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for i in range(1,3):
    values5=bank5[cat5[i]].value_counts().values
    keys5=bank5[cat5[i]].value_counts().keys()
    bankdf5=pd.DataFrame(zip(keys5,values5),columns=[cat5[i],'values'])
    print(f"......................{cat5[i]}.........")
    print(bankdf5)
bankdf5
# Out:
# ......................marital.........
#     marital  values
# 0   married    2797
# 1    single    1196
# 2  divorced     528
# ......................education.........
#    education  values
# 0  secondary    2306
# 1   tertiary    1350
# 2    primary     678
# 3    unknown     187
#    education  values
# 0  secondary    2306
# 1   tertiary    1350
# 2    primary     678
# 3    unknown     187

# %%
plt.figure(figsize=(10,5))
for i in range(1,3):
    keys5=bank5[cat5[i]].value_counts().keys()
    value5=bank5[cat5[i]].value_counts().values
    value_uni5=bank5[cat5[i]].unique()
    plt.subplot(2,2,i).pie(value5,labels=keys5,autopct='%0.2f%%',
                          explode=[0.1 for i in range(len(value_uni5))],
                          shadow=True,
                          startangle=360)

# %%
bank5.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank_d5=bank5['duration']

# %%
bank_d5
# Out:
# 0        79
# 1       220
# 2       185
# 3       199
# 4       226
#        ...
# 4516    329
# 4517    153
# 4518    151
# 4519    129
# 4520    345
# Name: duration, Length: 4521, dtype: int64

# %%
plt.hist(bank_d5)
# Out:
# (array([3.285e+03, 8.250e+02, 2.670e+02, 9.100e+01, 2.900e+01, 1.600e+01,
#         5.000e+00, 0.000e+00, 1.000e+00, 2.000e+00]),
#  array([   4. ,  306.1,  608.2,  910.3, 1212.4, 1514.5, 1816.6, 2118.7,
#         2420.8, 2722.9, 3025. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(bank_d5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23aa67fd010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23aa6985a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23aa64ece60>],
#  'medians': [<matplotlib.lines.Line2D at 0x23aa6985eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23aa69861b0>],
#  'means': []}

# %%
plt.boxplot(bank_d5,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23aa6ad3aa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23aa6af4050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23aa6ad3830>],
#  'medians': [<matplotlib.lines.Line2D at 0x23aa6af4470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23aa6af4740>],
#  'means': []}

# %%
plt.subplot(2,1,1).hist(bank_d5)
plt.subplot(2,1,2).boxplot(bank_d5,vert=False)
plt.show()

# %%
id_col=bank5['marital']
col=bank5['poutcome']
r5=pd.crosstab(id_col,col)
r5
# Out:
# poutcome  failure  other  success  unknown
# marital
# divorced       52     23       10      443
# married       298    112       82     2305
# single        140     62       37      957

# %%
id_col=bank5['marital']
col=bank5['poutcome']
r5=pd.crosstab(col,id_col)
r5
# Out:
# marital   divorced  married  single
# poutcome
# failure         52      298     140
# other           23      112      62
# success         10       82      37
# unknown        443     2305     957

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='marital'>

# %%
bank5.corr(numeric_only=True)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
corr5=bank5.corr(numeric_only=True)
sns.heatmap(corr5,annot=True)
# Out:
# <Axes: >

# %%
bank5
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
col1=bank5['pdays']
col2=bank5['duration']
col3=bank5['balance']
plt.figure(figsize=(14,8))
plt.subplot(1,3,1).scatter(col1,col2)
plt.subplot(1,3,2).scatter(col1,col3)
plt.subplot(1,3,3).scatter(col2,col3)
